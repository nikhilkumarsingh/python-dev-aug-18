# %% [markdown]
# ![](https://i.imgur.com/A3Cxp7P.png)
#
# ----
#
# - [Some analysis of Goals...](#Some-analysis-of-Goals...)
#     - [Goals scored vs conceded per team](#Goals-scored-vs-conceded-per-team)
#     - [Goal period](#Goal-period)
#     - [Shirt number matters...](#Shirt-number-matters...)
#
#
# - [Some team analysis...](#Some-team-analysis...)
#     - [What was the best stage native/foreign coaches were able to take their team to?](#What-was-the-best-stage-native/foreign-coaches-were-able-to-take-their-team-to?)
#
#
# - [Some analysis on players...](#Some-analysis-on-players...)
#     - [Goalkeepers are biggg!!!](#Goalkeepers-are-biggg!!!)
#     - [Some age analysis](#Some-age-analysis)
#     - [None of the teams with average age above 28 could make it past Quarterfinals...](#None-of-the-teams-with-average-age-above-28-could-make-it-past-Quarterfinals...)
#
#
# - [Some match attendance analysis...](#Some-match-attendance-analysis...)
#     - [Why so low attendance in quarters? Maybe bcoz of no Portugal, Spain and Argentina!](#Why-so-low-attendance-in-quarters?-Maybe-bcoz-of-no-Portugal,-Spain-and-Argentina!)
#
#
# - [Some analysis on team tactics...](#Some-analysis-on-team-tactics...)
#     - [4-2-3-1 seems to be everyone's favorite. Does it guarantee a win?](#4-2-3-1-seems-to-be-everyone's-favorite.-Does-it-guarantee-a-win?)
#     - [How does 4-2-3-1 tactic fares at big stage?](#How-does-4-2-3-1-tactic-fares-at-big-stage?)
#
#
# - [Some analysis on ball possession...](#Some-analysis-on-ball-possession...)
#     - [In 4/6 matches, France had lesser ball possession than the opponent..](#In-4/6-matches,-France-had-lesser-ball-possession-than-the-opponent..)
#
# ----

# %%
import pandas as pd
# %matplotlib inline

# %%
teams_df = pd.read_csv("data/teams.csv", index_col="IdTeam")

# %%
teams_df.head()
# Out:
#        TeamName           CoachName CoachCountry
# IdTeam
# 43929      Peru      GARECA Ricardo    Argentina
# 43872   Morocco        RENARD Herve       France
# 43855     Egypt        CUPER Hector    Argentina
# 43817   IR Iran      QUEIROZ Carlos     Portugal
# 43911    Mexico  OSORIO Juan Carlos     Colombia

# %%
players_df = pd.read_csv("data/players.csv", parse_dates=['BirthDate'], index_col="IdPlayer")

# %%
players_df.head()
# Out:
#                          Name TeamName    Position  BirthDate  Weight  Height  \
# IdPlayer
# 275261          Pedro GALLESE     Peru  Goalkeeper 1990-02-23    79.0   189.0
# 202638      Alberto RODRIGUEZ     Peru    Defender 1984-03-31    78.0   179.0
# 306194             Aldo CORZO     Peru    Defender 1989-05-20    75.0   172.0
# 398457    Anderson SANTAMARIA     Peru    Defender 1992-01-10    84.0   183.0
# 368000          Miguel ARAUJO     Peru    Defender 1994-10-24    77.0   178.0
#
#           InternationalCaps  Goals
# IdPlayer
# 275261                   42      0
# 202638                   75      0
# 306194                   24      0
# 398457                    8      0
# 368000                    8      0

# %%
matches_df = pd.read_csv("data/matches.csv", parse_dates=['Date'], index_col="IdMatch")

# %%
matches_df.head()
# Out:
#           HomeTeamName  AwayTeamName  Attendance  MatchDay  \
# IdMatch
# 300331503       Russia  Saudi Arabia       78011         1
# 300353632        Egypt       Uruguay       27015         2
# 300331526      Morocco       IR Iran       62548         2
# 300331524     Portugal         Spain       43866         2
# 300331533       France     Australia       41279         3
#
#                          Date        Stage HomeTeamTactics AwayTeamTactics  \
# IdMatch
# 300331503 2018-06-14 15:00:00  First stage         4-2-3-1           4-5-1
# 300353632 2018-06-15 12:00:00  First stage         4-2-3-1           4-4-2
# 300331526 2018-06-15 15:00:00  First stage           3-4-3           3-4-3
# 300331524 2018-06-15 18:00:00  First stage         4-2-3-1         4-2-3-1
# 300331533 2018-06-16 10:00:00  First stage           4-3-3         4-2-3-1
#
#            HomeTeamScore  AwayTeamScore   ...     MatchStatus  ResultType  \
# IdMatch                                   ...
# 300331503              5              0   ...               0           1
# 300353632              0              1   ...               0           1
# 300331526              0              1   ...               0           1
# 300331524              3              3   ...               0           1
# 300331533              2              1   ...               0           1
#
#                         StadiumName  Temperature  Humidity WindSpeed  \
# IdMatch
# 300331503          Luzhniki Stadium           17        43         6
# 300353632        Ekaterinburg Arena           14        42        29
# 300331526  Saint Petersburg Stadium           25        37        13
# 300331524             Fisht Stadium           24        74        10
# 300331533               Kazan Arena           19        32        19
#
#                    WeatherType  BallPossessionHome  BallPossessionAway  \
# IdMatch
# 300331503        Partly Cloudy                40.0                60.0
# 300353632        Partly Cloudy                43.0                57.0
# 300331526        Partly Cloudy                64.0                36.0
# 300331524  Partly Cloudy Night                39.0                61.0
# 300331533                Sunny                51.0                49.0
#
#             Winner
# IdMatch
# 300331503   Russia
# 300353632  Uruguay
# 300331526  IR Iran
# 300331524      NaN
# 300331533   France
#
# [5 rows x 23 columns]

# %%
goals_df = pd.read_csv("data/goals.csv")

# %%
goals_df.head()
# Out:
#           PlayerName  Minute    IdMatch  Type TeamName OppositionTeamName  \
# 0      Iury GAZINSKY     12'  300331503     2   Russia       Saudi Arabia
# 1    Denis CHERYSHEV     43'  300331503     2   Russia       Saudi Arabia
# 2       Artem DZYUBA     71'  300331503     2   Russia       Saudi Arabia
# 3    Denis CHERYSHEV  90'+1'  300331503     2   Russia       Saudi Arabia
# 4  Aleksandr GOLOVIN  90'+4'  300331503     2   Russia       Saudi Arabia
#
#    Position  IsCaptain      GoalKeeperName  PlayerShirtNumber
# 0         2      False  ABDULLAH ALMUAIOUF                  8
# 1         2      False  ABDULLAH ALMUAIOUF                  6
# 2         3      False  ABDULLAH ALMUAIOUF                 22
# 3         2      False  ABDULLAH ALMUAIOUF                  6
# 4         2      False  ABDULLAH ALMUAIOUF                 17

# %% [markdown]
# ## Some analysis of Goals...
# ![](https://i.imgflip.com/219r12.jpg)

# %% [markdown]
# ### Goals scored vs conceded per team

# %%
goals_scored_per_team = goals_df['TeamName'].value_counts()

# %%
goals_scored_per_team
# Out:
# Croatia           21
# Russia            18
# Belgium           16
# England           16
# France            14
# Spain             10
# Colombia           9
# Brazil             8
# Uruguay            7
# Sweden             6
# Argentina          6
# Japan              6
# Portugal           6
# Switzerland        5
# Tunisia            5
# Denmark            5
# Senegal            4
# Nigeria            3
# Korea Republic     3
# Mexico             3
# Germany            2
# Saudi Arabia       2
# Iceland            2
# Poland             2
# Costa Rica         2
# Australia          2
# Morocco            2
# IR Iran            2
# Serbia             2
# Panama             2
# Egypt              2
# Peru               2
# Name: TeamName, dtype: int64

# %%
goals_conceded_per_team = goals_df['OppositionTeamName'].value_counts()

# %%
goals_conceded_per_team
# Out:
# Croatia           14
# Russia            14
# Panama            11
# England           11
# Spain             10
# Argentina          9
# Tunisia            8
# Japan              7
# Saudi Arabia       7
# Colombia           7
# France             6
# Portugal           6
# Belgium            6
# Mexico             6
# Egypt              6
# Australia          5
# Switzerland        5
# Costa Rica         5
# Poland             5
# Iceland            5
# Denmark            5
# Senegal            4
# Morocco            4
# Nigeria            4
# Sweden             4
# Germany            4
# Serbia             4
# Korea Republic     3
# Uruguay            3
# Brazil             3
# Peru               2
# IR Iran            2
# Name: OppositionTeamName, dtype: int64

# %%
goals_scored_per_team.get('Croatia')
# Out:
# 21

# %%
teams_df['GoalsScored'] = teams_df['TeamName'].apply(goals_scored_per_team.get)

# %%
teams_df['GoalsConceded'] = teams_df['TeamName'].apply(goals_conceded_per_team.get)

# %%
# goals scored vs conceded
teams_df.plot.bar(x='TeamName', y=['GoalsScored', 'GoalsConceded'], figsize=(15,6))

# %%
teams_df[teams_df['GoalsScored'] < teams_df['GoalsConceded']]
# Out:
#              TeamName            CoachName CoachCountry  GoalsScored  \
# IdTeam
# 43872         Morocco         RENARD Herve       France            2
# 43855           Egypt         CUPER Hector    Argentina            2
# 43911          Mexico   OSORIO Juan Carlos     Colombia            3
# 43835    Saudi Arabia   PIZZI Juan Antonio        Spain            2
# 43962          Poland         NAWALKA Adam       Poland            2
# 43819           Japan        NISHINO Akira        Japan            6
# 43914          Panama         GOMEZ Hernan     Colombia            2
# 43888         Tunisia        MAALOUL Nabil      Tunisia            5
# 43976       Australia     VAN MARWIJK Bert  Netherlands            2
# 43948         Germany          LÖW Joachim      Germany            2
# 43901      Costa Rica        RAMIREZ Oscar   Costa Rica            2
# 1902465        Serbia      KRSTAJIC Mladen       Serbia            2
# 43951         Iceland  HALLGRIMSSON Heimir      Iceland            2
# 43876         Nigeria          ROHR Gernot      Germany            3
# 43922       Argentina       SAMPAOLI Jorge    Argentina            6
#
#          GoalsConceded
# IdTeam
# 43872                4
# 43855                6
# 43911                6
# 43835                7
# 43962                5
# 43819                7
# 43914               11
# 43888                8
# 43976                5
# 43948                4
# 43901                5
# 1902465              4
# 43951                5
# 43876                4
# 43922                9

# %%
# Which teams conceded more goals than they scored?
teams_df.query('GoalsScored < GoalsConceded')
# Out:
#              TeamName            CoachName CoachCountry  GoalsScored  \
# IdTeam
# 43872         Morocco         RENARD Herve       France            2
# 43855           Egypt         CUPER Hector    Argentina            2
# 43911          Mexico   OSORIO Juan Carlos     Colombia            3
# 43835    Saudi Arabia   PIZZI Juan Antonio        Spain            2
# 43962          Poland         NAWALKA Adam       Poland            2
# 43819           Japan        NISHINO Akira        Japan            6
# 43914          Panama         GOMEZ Hernan     Colombia            2
# 43888         Tunisia        MAALOUL Nabil      Tunisia            5
# 43976       Australia     VAN MARWIJK Bert  Netherlands            2
# 43948         Germany          LÖW Joachim      Germany            2
# 43901      Costa Rica        RAMIREZ Oscar   Costa Rica            2
# 1902465        Serbia      KRSTAJIC Mladen       Serbia            2
# 43951         Iceland  HALLGRIMSSON Heimir      Iceland            2
# 43876         Nigeria          ROHR Gernot      Germany            3
# 43922       Argentina       SAMPAOLI Jorge    Argentina            6
#
#          GoalsConceded
# IdTeam
# 43872                4
# 43855                6
# 43911                6
# 43835                7
# 43962                5
# 43819                7
# 43914               11
# 43888                8
# 43976                5
# 43948                4
# 43901                5
# 1902465              4
# 43951                5
# 43876                4
# 43922                9

# %% [markdown]
# ### Goal period

# %%
def set_goal_period(minute):
    total = eval(minute.replace('\'', ''))
    if "45'+" in minute or total<=45:
        return "FirstHalf"
    elif  "90'+" in minute or 45<total<=90:
        return "SecondHalf"
    elif 90<total<=120:
        return "ExtraTime"
    else:
        return "PenaltyShootout"

# %%
goals_df['Period'] = goals_df['Minute'].apply(set_goal_period)

# %%
goals_df['Period'].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# ### Shirt number matters...

# %%
# 10 vs 7
goals_df['PlayerShirtNumber'].value_counts()
# Out:
# 10    27
# 7     20
# 9     20
# 4     15
# 19    12
# 11    12
# 6     10
# 17     8
# 21     7
# 20     7
# 15     7
# 8      7
# 22     7
# 13     6
# 14     6
# 2      6
# 5      5
# 18     4
# 3      2
# 23     2
# 12     2
# 16     2
# 1      1
# Name: PlayerShirtNumber, dtype: int64

# %%
# players with shirt no. 10 who scored goals 
goals_df.query("PlayerShirtNumber == 10")['PlayerName'].value_counts()
# Out:
# Kylian MBAPPE          4
# Luka MODRIC            4
# Eden HAZARD            3
# NEYMAR                 2
# Wahbi KHAZRI           2
# MOHAMED SALAH          2
# Karim ANSARIFARD       1
# Granit XHAKA           1
# Fedor SMOLOV           1
# Gylfi SIGURDSSON       1
# Grzegorz KRYCHOWIAK    1
# Emil FORSBERG          1
# Christian ERIKSEN      1
# Sadio MANE             1
# Lionel MESSI           1
# Shinji KAGAWA          1
# Name: PlayerName, dtype: int64

# %% [markdown]
# ## Some team analysis...
# ![](https://michaelsloredotcom.files.wordpress.com/2017/12/545399686-france-team-members-celebrate-after-beating-germany-2-0-crop-promo-xlarge2-e1512248877901.jpg?w=845&h=450&crop=1)

# %%
# Best stage teams made?
best_stage_map = {}
for i in range(len(matches_df.index)):
    match = matches_df.iloc[i]
    best_stage_map[match['HomeTeamName']] = match['Stage']
    best_stage_map[match['AwayTeamName']] = match['Stage']

# %%
best_stage_map
# Out:
# {'Russia': 'Quarter-finals',
#  'Saudi Arabia': 'First stage',
#  'Egypt': 'First stage',
#  'Uruguay': 'Quarter-finals',
#  'Morocco': 'First stage',
#  'IR Iran': 'First stage',
#  'Portugal': 'Round of 16',
#  'Spain': 'Round of 16',
#  'France': 'Final',
#  'Australia': 'First stage',
#  'Argentina': 'Round of 16',
#  'Iceland': 'First stage',
#  'Peru': 'First stage',
#  'Denmark': 'Round of 16',
#  'Croatia': 'Final',
#  'Nigeria': 'First stage',
#  'Costa Rica': 'First stage',
#  'Serbia': 'First stage',
#  'Germany': 'First stage',
#  'Mexico': 'Round of 16',
#  'Brazil': 'Quarter-finals',
#  'Switzerland': 'Round of 16',
#  'Sweden': 'Quarter-finals',
#  'Korea Republic': 'First stage',
#  'Belgium': 'Play-off for third place',
#  'Panama': 'First stage',
#  'Tunisia': 'First stage',
#  'England': 'Play-off for third place',
#  'Colombia': 'Round of 16',
#  'Japan': 'Round of 16',
#  'Poland': 'First stage',
#  'Senegal': 'First stage'}

# %%
teams_df['BestStage'] = teams_df['TeamName'].apply(best_stage_map.get)

# %% [markdown]
# ### What was the best stage native/foreign coaches were able to take their team to?

# %%
teams_df.query('TeamName != CoachCountry')['BestStage'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
teams_df.query('TeamName == CoachCountry')['BestStage'].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# ## Some analysis on players...
# ![](http://n.sinaimg.cn/sports/transform/224/w615h409/20180707/hZYi-hexfcvm1472143.jpg)

# %%
players_df['Height'].plot.hist()

# %%
# Who is tallest player?
players_df.loc[players_df['Height'].idxmax()]
# Out:
# Name                       Lovre KALINIC
# TeamName                         Croatia
# Position                      Goalkeeper
# BirthDate            1990-04-03 00:00:00
# Weight                                96
# Height                               201
# InternationalCaps                     12
# Goals                                  0
# Name: 376287, dtype: object

# %%
# who is the tiniest?
players_df.loc[players_df['Height'].idxmin()]
# Out:
# Name                      YAHIA ALSHEHRI
# TeamName                    Saudi Arabia
# Position                      Midfielder
# BirthDate            1990-06-26 00:00:00
# Weight                                63
# Height                               165
# InternationalCaps                     58
# Goals                                  7
# Name: 347165, dtype: object

# %%
# Player position breakdown
players_df.Position.value_counts()
# Out:
# Defender      247
# Midfielder    234
# Forward       159
# Goalkeeper     96
# Name: Position, dtype: int64

# %%
def get_position_color(position):
    color_map = {
        "Defender": 'y',
        "Midfielder": 'b',
        "Forward": 'g',
        "Goalkeeper": 'r'
    }
    return color_map[position]

# %%
color_map = players_df['Position'].apply(get_position_color)

# %%
players_df.plot.scatter(x='Height', y='Weight', c=color_map)

# %%
players_df.groupby('Position')[['Height', 'Weight']].mean()
# Out:
#                 Height     Weight
# Position
# Defender    183.178138  78.028340
# Forward     181.327044  76.735849
# Goalkeeper  188.770833  83.500000
# Midfielder  179.816239  74.145299

# %% [markdown]
# ### Goalkeepers are biggg!!!
# ![](https://i.imgur.com/v81dlTt.jpg)

# %% [markdown]
# ### Some age analysis
#
# ![](https://t.resfu.com/media/img_news/montage-of-essam-el-hadary-and-kylian-mbappe--besoccer.png?size=776x&q=60)

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
players_df['Age'] = (now - players_df['BirthDate']).astype('<m8[Y]')

# %%
players_df.head()
# Out:
#                          Name TeamName    Position  BirthDate  Weight  Height  \
# IdPlayer
# 275261          Pedro GALLESE     Peru  Goalkeeper 1990-02-23    79.0   189.0
# 202638      Alberto RODRIGUEZ     Peru    Defender 1984-03-31    78.0   179.0
# 306194             Aldo CORZO     Peru    Defender 1989-05-20    75.0   172.0
# 398457    Anderson SANTAMARIA     Peru    Defender 1992-01-10    84.0   183.0
# 368000          Miguel ARAUJO     Peru    Defender 1994-10-24    77.0   178.0
#
#           InternationalCaps  Goals   Age
# IdPlayer
# 275261                   42      0  28.0
# 202638                   75      0  34.0
# 306194                   24      0  29.0
# 398457                    8      0  26.0
# 368000                    8      0  23.0

# %%
# Who are the oldest players?
players_df.sort_values('Age', ascending=False).head()
# Out:
#                         Name   TeamName    Position  BirthDate  Weight  \
# IdPlayer
# 155050        ESSAM ELHADARY      Egypt  Goalkeeper 1973-01-15    90.0
# 186787    Sergey IGNASHEVICH     Russia    Defender 1979-07-14    84.0
# 178119        Rafael MARQUEZ     Mexico    Defender 1979-02-13    77.0
# 213001            Tim CAHILL  Australia     Forward 1979-12-06    76.0
# 181440    Wilfredo CABALLERO  Argentina  Goalkeeper 1981-09-28    80.0
#
#           Height  InternationalCaps  Goals   Age
# IdPlayer
# 155050     190.0                159      0  45.0
# 186787     186.0                127      9  39.0
# 178119     184.0                148     15  39.0
# 213001     180.0                107     50  38.0
# 181440     186.0                  5      0  37.0

# %%
# Who are the youngest players?
players_df.sort_values('Age').head()
# Out:
#                    Name   TeamName    Position  BirthDate  Weight  Height  \
# IdPlayer
# 389503    Daniel ARZANI  Australia     Forward 1999-01-04    73.0   171.0
# 400721    Achraf HAKIMI    Morocco    Defender 1998-11-04    65.0   179.0
# 372607    Francis UZOHO    Nigeria  Goalkeeper 1998-10-28    91.0   196.0
# 389867    Kylian MBAPPE     France     Forward 1998-12-20    78.0   178.0
# 386256     Moussa WAGUE    Senegal    Defender 1998-10-04    70.0   177.0
#
#           InternationalCaps  Goals   Age
# IdPlayer
# 389503                    5      1  19.0
# 400721                   15      1  19.0
# 372607                    9      0  19.0
# 389867                   22      8  19.0
# 386256                   10      1  20.0

# %%
avg_country_ages = players_df.groupby('TeamName')['Age'].mean().sort_values()

# %%
teams_df["AverageAge"] = teams_df['TeamName'].apply(avg_country_ages.get)

# %% [markdown]
# ### None of the teams with average age above 28 could make it past Quarterfinals...

# %%
teams_df.sort_values('AverageAge')[['TeamName', 'AverageAge', 'BestStage']]
# Out:
#                TeamName  AverageAge                 BestStage
# IdTeam
# 43876           Nigeria   25.652174               First stage
# 43942           England   25.826087  Play-off for third place
# 43946            France   25.826087                     Final
# 43888           Tunisia   26.347826               First stage
# 1902465          Serbia   26.521739               First stage
# 43879           Senegal   26.739130               First stage
# 43948           Germany   26.956522               First stage
# 43971       Switzerland   27.000000               Round of 16
# 43941           Denmark   27.043478               Round of 16
# 43872           Morocco   27.086957               First stage
# 43929              Peru   27.260870               First stage
# 43817           IR Iran   27.260870               First stage
# 43935           Belgium   27.434783  Play-off for third place
# 43822    Korea Republic   27.652174               First stage
# 43938           Croatia   27.695652                     Final
# 43930           Uruguay   27.956522            Quarter-finals
# 43976         Australia   27.956522               First stage
# 43970            Sweden   28.086957            Quarter-finals
# 43962            Poland   28.173913               First stage
# 43963          Portugal   28.217391               Round of 16
# 43926          Colombia   28.260870               Round of 16
# 43969             Spain   28.304348               Round of 16
# 43951           Iceland   28.391304               First stage
# 43819             Japan   28.434783               Round of 16
# 43835      Saudi Arabia   28.608696               First stage
# 43924            Brazil   28.608696            Quarter-finals
# 43914            Panama   28.652174               First stage
# 43965            Russia   28.652174            Quarter-finals
# 43855             Egypt   28.826087               First stage
# 43911            Mexico   29.130435               Round of 16
# 43922         Argentina   29.304348               Round of 16
# 43901        Costa Rica   29.565217               First stage

# %% [markdown]
# ## Some match attendance analysis...
# ![](https://i.imgur.com/MyTtkVy.jpg)

# %%
# Attendance in France matches
matches_df.query("HomeTeamName == 'France' or AwayTeamName == 'France'").plot.bar(x="Stage", y="Attendance", figsize=(15,7))

# %%
def get_avg_team_attendance(team_name):
    return matches_df.query("HomeTeamName == '{0}' or AwayTeamName == '{0}'".format(team_name))["Attendance"].mean()

# %%
teams_df['AvgAttendance'] = teams_df['TeamName'].apply(get_avg_team_attendance)

# %%
teams_df[['TeamName', 'AvgAttendance', 'BestStage']].sort_values('AvgAttendance', ascending=False)
# Out:
#                TeamName  AvgAttendance                 BestStage
# IdTeam
# 43965            Russia   61349.400000            Quarter-finals
# 43872           Morocco   58177.333333               First stage
# 43948           Germany   54711.000000               First stage
# 43946            France   54366.857143                     Final
# 43835      Saudi Arabia   52504.000000               First stage
# 43963          Portugal   51962.250000               Round of 16
# 43938           Croatia   51298.142857                     Final
# 43941           Denmark   50022.750000               Round of 16
# 43901        Costa Rica   49739.666667               First stage
# 43969             Spain   49642.000000               Round of 16
# 43942           England   49279.142857  Play-off for third place
# 43911            Mexico   49128.500000               Round of 16
# 43817           IR Iran   48983.666667               First stage
# 43922         Argentina   48712.500000               Round of 16
# 43935           Belgium   47778.714286  Play-off for third place
# 43924            Brazil   47322.000000            Quarter-finals
# 43971       Switzerland   45909.250000               Round of 16
# 43876           Nigeria   45502.666667               First stage
# 43970            Sweden   44736.200000            Quarter-finals
# 43962            Poland   43084.000000               First stage
# 43951           Iceland   42855.333333               First stage
# 43855             Egypt   42768.666667               First stage
# 43822    Korea Republic   42535.666667               First stage
# 43926          Colombia   42468.750000               Round of 16
# 43976         Australia   42026.333333               First stage
# 43914            Panama   41248.000000               First stage
# 43888           Tunisia   40807.333333               First stage
# 43930           Uruguay   39853.800000            Quarter-finals
# 1902465          Serbia   39596.333333               First stage
# 43879           Senegal   39577.333333               First stage
# 43819             Japan   39267.250000               Round of 16
# 43929              Peru   39121.333333               First stage

# %%
# Stage wise average attendance
matches_df.groupby("Stage")['Attendance'].mean().sort_values(ascending=False)
# Out:
# Stage
# Final                       78011.000
# Semi-finals                 71148.500
# Play-off for third place    64406.000
# Round of 16                 49711.250
# First stage                 45393.625
# Quarter-finals              42617.500
# Name: Attendance, dtype: float64

# %%
matches_df.groupby("Stage")['Attendance'].mean().sort_values(ascending=False).plot.bar()

# %% [markdown]
# ### Why so low attendance in quarters? Maybe bcoz of no Portugal, Spain and Argentina!

# %% [markdown]
# ## Some analysis on team tactics...
# ![](https://theresonlyoneball.files.wordpress.com/2018/01/tactics.png?w=648)

# %%
matches_df["HomeTeamTactics"].value_counts()
# Out:
# 4-2-3-1    33
# 4-4-2      10
# 3-4-3       6
# 3-5-2       5
# 4-3-3       4
# 4-5-1       3
# 5-4-1       1
# 3-4-2-1     1
# 4-3-2-1     1
# Name: HomeTeamTactics, dtype: int64

# %% [markdown]
# ### 4-2-3-1 seems to be everyone's favorite. Does it guarantee a win?

# %%
def set_winning_team_tactics(match):
    if match["Winner"] == match["HomeTeamName"]:
        return match["HomeTeamTactics"]
    elif match["Winner"] == match["AwayTeamName"]:
        return match["AwayTeamTactics"]
    else:
        return None

# %%
matches_df["WinningTeamTactics"] = matches_df.apply(set_winning_team_tactics, axis=1)

# %%
matches_df["WinningTeamTactics"].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# ### 4-2-3-1 is used by the winning team maximum number of times...what about losing teams' tactics?

# %%
def set_losing_team_tactics(match):
    if match["Winner"] == match["HomeTeamName"]:
        return match["AwayTeamTactics"]
    elif match["Winner"] == match["AwayTeamName"]:
        return match["HomeTeamTactics"]
    else:
        return None

# %%
matches_df["LosingTeamTactics"] = matches_df.apply(set_losing_team_tactics, axis=1)

# %%
matches_df["LosingTeamTactics"].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# ### How does 4-2-3-1 tactic fares at big stage?

# %%
matches_df.query("WinningTeamTactics == '4-2-3-1' and Stage != 'First stage'")
# Out:
#           HomeTeamName AwayTeamName  Attendance  MatchDay                Date  \
# IdMatch
# 300331537       France    Argentina       42873        16 2018-06-30 14:00:00
# 300331498      Croatia      Denmark       40851        17 2018-07-01 18:00:00
# 300331535       Brazil       Mexico       41970        18 2018-07-02 14:00:00
# 300331543      Uruguay       France       43319        20 2018-07-06 14:00:00
# 300331504       Russia      Croatia       44287        21 2018-07-07 18:00:00
# 300331531       France      Belgium       64286        22 2018-07-10 18:00:00
# 300331522      Croatia      England       78011        23 2018-07-11 18:00:00
# 300331552       France      Croatia       78011        25 2018-07-15 15:00:00
#
#                     Stage HomeTeamTactics AwayTeamTactics  HomeTeamScore  \
# IdMatch
# 300331537     Round of 16         4-2-3-1           4-3-3              4
# 300331498     Round of 16         4-2-3-1           4-3-3              1
# 300331535     Round of 16         4-2-3-1           4-3-3              2
# 300331543  Quarter-finals           4-4-2         4-2-3-1              0
# 300331504  Quarter-finals         4-2-3-1         4-2-3-1              2
# 300331531     Semi-finals         4-2-3-1           3-5-2              1
# 300331522     Semi-finals         4-2-3-1           3-5-2              2
# 300331552           Final         4-2-3-1         4-2-3-1              4
#
#            AwayTeamScore        ...                      StadiumName  \
# IdMatch                         ...
# 300331537              3        ...                      Kazan Arena
# 300331498              1        ...          Nizhny Novgorod Stadium
# 300331535              0        ...                     Samara Arena
# 300331543              2        ...          Nizhny Novgorod Stadium
# 300331504              2        ...                    Fisht Stadium
# 300331531              0        ...         Saint Petersburg Stadium
# 300331522              1        ...                 Luzhniki Stadium
# 300331552              2        ...                 Luzhniki Stadium
#
#            Temperature  Humidity  WindSpeed          WeatherType  \
# IdMatch
# 300331537           28        33         12                Sunny
# 300331498           25        48         15  Partly Cloudy Night
# 300331535           33        28         14                Sunny
# 300331543           22        53         13        Partly Cloudy
# 300331504           24        70         12          Clear Night
# 300331531           18        75         11               Cloudy
# 300331522           21        64          6               Cloudy
# 300331552           27        51          3        Partly Cloudy
#
#           BallPossessionHome  BallPossessionAway   Winner  WinningTeamTactics  \
# IdMatch
# 300331537               41.0                59.0   France             4-2-3-1
# 300331498               54.0                46.0  Croatia             4-2-3-1
# 300331535               47.0                53.0   Brazil             4-2-3-1
# 300331543               42.0                58.0   France             4-2-3-1
# 300331504               38.0                62.0  Croatia             4-2-3-1
# 300331531               40.0                60.0   France             4-2-3-1
# 300331522               54.0                46.0  Croatia             4-2-3-1
# 300331552               39.0                61.0   France             4-2-3-1
#
#           LosingTeamTactics
# IdMatch
# 300331537             4-3-3
# 300331498             4-3-3
# 300331535             4-3-3
# 300331543             4-4-2
# 300331504           4-2-3-1
# 300331531             3-5-2
# 300331522             3-5-2
# 300331552           4-2-3-1
#
# [8 rows x 25 columns]

# %%
matches_df.iloc[-1]
# Out:
# HomeTeamName                         France
# AwayTeamName                        Croatia
# Attendance                            78011
# MatchDay                                 25
# Date                    2018-07-15 15:00:00
# Stage                                 Final
# HomeTeamTactics                     4-2-3-1
# AwayTeamTactics                     4-2-3-1
# HomeTeamScore                             4
# AwayTeamScore                             2
# HomeTeamPenaltyScore                      0
# AwayTeamPenaltyScore                      0
# IsHomeMatch                             NaN
# MatchStatus                               0
# ResultType                                1
# StadiumName                Luzhniki Stadium
# Temperature                              27
# Humidity                                 51
# WindSpeed                                 3
# WeatherType                   Partly Cloudy
# BallPossessionHome                       39
# BallPossessionAway                       61
# Winner                               France
# WinningTeamTactics                  4-2-3-1
# LosingTeamTactics                   4-2-3-1
# Name: 300331552, dtype: object

# %% [markdown]
# ![](https://img.memecdn.com/leaked-portugal-world-cup-tactics_o_3411817.jpg)

# %% [markdown]
# ## Some analysis on ball possession...
#
# ![](https://sportzwiki.com/wp-content/uploads/2018/03/sprinkle.jpg)

# %%
def set_winning_team_ball_possession(match):
    if match["Winner"] == match["HomeTeamName"]:
        return match["BallPossessionHome"]
    elif match["Winner"] == match["AwayTeamName"]:
        return match["BallPossessionAway"]
    else:
        return None
    
def set_losing_team_ball_possession(match):
    if match["Winner"] == match["HomeTeamName"]:
        return match["BallPossessionAway"]
    elif match["Winner"] == match["AwayTeamName"]:
        return match["BallPossessionHome"]
    else:
        return None

# %%
matches_df["BallPossessionWinner"] = matches_df.apply(set_winning_team_ball_possession, axis=1)
matches_df["BallPossessionLoser"] = matches_df.apply(set_losing_team_ball_possession, axis=1)

# %%
len(matches_df)
# Out:
# 64

# %%
matches_df.query("BallPossessionWinner < BallPossessionLoser").describe(include='object')
# Out:
#        HomeTeamName  AwayTeamName        Stage HomeTeamTactics  \
# count            23            23           23              23
# unique           17            18            6               3
# top          France  Saudi Arabia  First stage         4-2-3-1
# freq              4             2           14              15
#
#        AwayTeamTactics               StadiumName    WeatherType  Winner  \
# count               23                        23             23      23
# unique               7                        11              5      15
# top            4-2-3-1  Saint Petersburg Stadium  Partly Cloudy  France
# freq                 9                         5              9       4
#
#        WinningTeamTactics LosingTeamTactics
# count                  23                23
# unique                  5                 6
# top               4-2-3-1           4-2-3-1
# freq                   10                14

# %% [markdown]
# ### In 4/7 matches, France had lesser ball possession than the opponent..

# %%
def get_avg_team_ball_possession(team_name):
    home_possessions = matches_df.query("HomeTeamName == '{0}'".format(team_name))["BallPossessionHome"]
    away_possessions = matches_df.query("AwayTeamName == '{0}'".format(team_name))["BallPossessionAway"]
    return (sum(home_possessions) + sum(away_possessions))/ (len(home_possessions) + len(away_possessions))

# %%
teams_df["AverageBallPossession"] = teams_df["TeamName"].apply(get_avg_team_ball_possession)

# %%
teams_df[["TeamName", "AverageBallPossession", "BestStage"]].sort_values(by="AverageBallPossession", ascending=False)
# Out:
#                TeamName  AverageBallPossession                 BestStage
# IdTeam
# 43969             Spain              68.500000               Round of 16
# 43948           Germany              67.000000               First stage
# 43922         Argentina              63.750000               Round of 16
# 43835      Saudi Arabia              58.000000               First stage
# 43971       Switzerland              57.250000               Round of 16
# 43924            Brazil              55.600000            Quarter-finals
# 43938           Croatia              55.142857                     Final
# 43911            Mexico              54.250000               Round of 16
# 43963          Portugal              53.750000               Round of 16
# 43942           England              53.714286  Play-off for third place
# 43819             Japan              52.750000               Round of 16
# 43935           Belgium              52.428571  Play-off for third place
# 43929              Peru              51.666667               First stage
# 43888           Tunisia              51.000000               First stage
# 43976         Australia              51.000000               First stage
# 43926          Colombia              50.500000               Round of 16
# 43872           Morocco              49.666667               First stage
# 43962            Poland              49.333333               First stage
# 43930           Uruguay              48.200000            Quarter-finals
# 43946            France              47.857143                     Final
# 43876           Nigeria              46.000000               First stage
# 1902465          Serbia              45.333333               First stage
# 43941           Denmark              45.250000               Round of 16
# 43855             Egypt              45.000000               First stage
# 43879           Senegal              44.000000               First stage
# 43901        Costa Rica              41.333333               First stage
# 43822    Korea Republic              39.666667               First stage
# 43970            Sweden              39.200000            Quarter-finals
# 43914            Panama              39.000000               First stage
# 43965            Russia              38.800000            Quarter-finals
# 43951           Iceland              37.000000               First stage
# 43817           IR Iran              32.666667               First stage

# %% [markdown]
# ![](http://ift.tt/UeVgbp)
